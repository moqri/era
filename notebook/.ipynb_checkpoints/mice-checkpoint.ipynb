# %%
import pandas as pd
import umap
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import hdbscan
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
data='../data/mice/'
epic_man='https://support.illumina.com/content/dam/illumina-support/documents/downloads/productfiles/mouse-methylation/MouseMethylation-12v1-0_A1_Annotation_Mus_musculus.csv'
#epic=pd.read_csv(epic_man,index_col=0,skiprows=7)

# %%
df=pd.read_csv(data+'meth.csv',index_col=0).T
df.shape
# Out:
# (144, 37492)

# %%
v=df.var()>.01
df=df[v[v].index]
df.shape
# Out:
# (144, 9666)

# %%
x = StandardScaler().fit_transform(df)
x.shape
# Out:
# (144, 9666)

# %%
pca = PCA(n_components=2)
principalComponents = pca.fit_transform(x)
dg = pd.DataFrame(data = principalComponents
             , columns = ['pc1', 'pc2'])
dg.index=df.index

# %%
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('pc1', fontsize = 15)
ax.set_ylabel('pc2', fontsize = 15)
ax.set_title('2 component PCA', fontsize = 20)
ax.scatter(dg.loc[:, 'pc1']
            , dg.loc[:, 'pc2']
               , s = 50)
ax.grid()

# %%
df=df.drop('205128010048_R04C01')
x = StandardScaler().fit_transform(df)
pca = PCA(n_components=2)
principalComponents = pca.fit_transform(x)
dg = pd.DataFrame(data = principalComponents
             , columns = ['pc1', 'pc2'])
dg.index=df.index
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('pc1', fontsize = 15)
ax.set_ylabel('pc2', fontsize = 15)
ax.set_title('2 component PCA', fontsize = 20)
ax.scatter(dg.loc[:, 'pc1']
            , dg.loc[:, 'pc2']
               , s = 50)
ax.grid()

# %%
reducer = umap.UMAP()
embedding = reducer.fit_transform(x)
embedding.shape
# Out:
# (143, 2)

# %%
plt.scatter(embedding[:, 0], embedding[:, 1])

# %%
labels = hdbscan.HDBSCAN(
    min_samples=5,
    min_cluster_size=5,
).fit_predict(embedding)

# %%
dg['cluster']=labels

# %%
clustered = (labels >= 0)

# %%
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('pc1', fontsize = 15)
ax.set_ylabel('pc2', fontsize = 15)
ax.set_title('2 component UMAP', fontsize = 20)
ax.scatter(embedding[clustered, 0],
            embedding[clustered, 1],
            c=labels[clustered],
            cmap='Spectral');
ax.grid()

# %%
dg.cluster.value_counts()
# Out:
# 6    37
# 0    18
# 1    18
# 2    18
# 3    18
# 5    18
# 4    16
# Name: cluster, dtype: int64

# %%
dg.to_csv(data+'clusters.csv')

# %%
hor=pd.read_csv(data+'HorvathMammal40.Manifest.May2020.manifest.csv',index_col=0)
# Out:
# /Users/mahdimoqri/miniconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3072: DtypeWarning: Columns (2,48,49,50,51,52,53,54,55,56) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
meta=pd.read_csv(data+'SampleSheetMinimal84.csv',index_col=1)
meta['g']=meta.ExternalSampleID.str[0].astype(int)
meta['m']=meta.ExternalSampleID.str[2].astype(int)
meta['t']=meta.ExternalSampleID.str[-2:]
meta.t.value_counts()
# Out:
# _S    36
# _K    18
# Lu    18
# Li    18
# _B    18
# _P    18
# _H    18
# Name: t, dtype: int64

# %%
meta=meta[meta.g==1&(meta.t=='_P')]

# %%
meta['d']=meta.m.replace({1:'n',2:'n',3:'n',4:'p',5:'p',6:'p'})

# %%
meta
# Out:
#                      OriginalOrderInBatch ExternalSampleID SpeciesCommonName  \
# Basename
# 205128010047_R05C01                     5            1_1_P             Mouse
# 205128010048_R01C01                    13            1_2_P             Mouse
# 205128010048_R03C02                    21            1_3_P             Mouse
# 205128010009_R05C01                    29            1_4_P             Mouse
# 205128010036_R01C01                    37            1_5_P             Mouse
# 205128010036_R03C02                    45            1_6_P             Mouse
#
#                     SpeciesLatinName  Tissue  Female  \
# Basename
# 205128010047_R05C01     Mus musculus     NaN       1
# 205128010048_R01C01     Mus musculus     NaN       0
# 205128010048_R03C02     Mus musculus     NaN       1
# 205128010009_R05C01     Mus musculus     NaN       1
# 205128010036_R01C01     Mus musculus     NaN       1
# 205128010036_R03C02     Mus musculus     NaN       1
#
#                                            Folder  g  m   t  d
# Basename
# 205128010047_R05C01  N84.2020-9196MouseSebastiano  1  1  _P  n
# 205128010048_R01C01  N84.2020-9196MouseSebastiano  1  2  _P  n
# 205128010048_R03C02  N84.2020-9196MouseSebastiano  1  3  _P  n
# 205128010009_R05C01  N84.2020-9196MouseSebastiano  1  4  _P  p
# 205128010036_R01C01  N84.2020-9196MouseSebastiano  1  5  _P  p
# 205128010036_R03C02  N84.2020-9196MouseSebastiano  1  6  _P  p

# %%
df1=df.merge(meta[['d','t']][meta.g==1],left_index=True,right_index=True)
df2=df.merge(meta[['d','t']][meta.g==2],left_index=True,right_index=True)
df3=df.merge(meta[['d','t']][meta.g==3],left_index=True,right_index=True)

# %%
dg=df1.groupby('d').median().T

# %%
dg['d']=dg['n']-dg['p']
dg.d.hist(bins=100)
# Out:
# <AxesSubplot:>

# %%
dg=dg[dg.d<-.1]
dg.shape
# Out:
# (1389, 3)

# %%
dg=hor.loc[dg.index]
dg.CHR.value_counts()
# Out:
# chr1     148
# chr2     101
# chr5      99
# chr3      95
# chrX      93
# chr9      82
# chr10     76
# chr17     72
# chr8      68
# chr7      55
# chr11     54
# chr12     50
# chr6      48
# chr15     46
# chr14     44
# chr16     43
# chr4      42
# chr13     36
# chr19     35
# chr18     33
# chr21     25
# chr20     25
# chr22     19
# Name: CHR, dtype: int64

# %%
dgh=df1[dg.index].T

# %%
dgh.columns=['n1','n2','n3','p1','p2','p3']
dgh.to_csv(data+'meth.csv')

# %%
dgh=hor.loc[dg.index][['HG38.seqnames','HG38.start','HG38.end','HG38.strand']]
dgh['HG38.start']=dgh['HG38.start'].astype(int)
dgh['HG38.end']=dgh['HG38.end'].astype(int)
dgh.reset_index(inplace=True,drop=True)
dgh.to_csv('dmh.txt',sep='\t')
dgh.shape
# Out:
# (1389, 4)

# %%
dgh
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-388ac509452e> in <module>
# ----> 1 dgh
#
# NameError: name 'dgh' is not defined
